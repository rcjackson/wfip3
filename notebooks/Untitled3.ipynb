# %%
import xarray as xr
import cmweather
import matplotlib.pyplot as plt
import numpy as np

# %%
ds = xr.open_mfdataset('/Users/rjackson/sp2/kcgaossp2bc60sS3.b1.2024*.nc')

# %%
ds['sp2_rbc_conc'].plot()
plt.ylim([0, 1000])
plt.savefig('sp2_rbc_conc.png')

# %%
np.log10(ds['sp2_cnts']).T.plot(vmin=-3, vmax=3, cmap='Spectral_r')
plt.savefig('sp2_
